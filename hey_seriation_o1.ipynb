# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/monteprediction_colab_examples/blob/main/hey_seriation_o1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hey Seriation
#
# I asked the new ChatGPT-o1 Preview to perform seriation of the following companies, placing those that are similar next to each other and conversely. You might want to try to do this yourself, using your own common sense.

# %%
companies = {
    'AAPL': 'Apple Inc.',
    'MSFT': 'Microsoft Corporation',
    'AMZN': 'Amazon.com, Inc.',
    'GOOGL': 'Alphabet Inc. Class A',
    'GOOG': 'Alphabet Inc. Class C',
    'META': 'Meta Platforms, Inc.',
    'TSLA': 'Tesla, Inc.',
    'NVDA': 'NVIDIA Corporation',
    'BRK-B': 'Berkshire Hathaway Inc. Class B',
    'JPM': 'JPMorgan Chase & Co.',
    'JNJ': 'Johnson & Johnson',
    'V': 'Visa Inc.',
    'UNH': 'UnitedHealth Group Incorporated',
    'PG': 'The Procter & Gamble Company',
    'HD': 'The Home Depot, Inc.',
    'MA': 'Mastercard Incorporated',
    'BAC': 'Bank of America Corporation',
    'DIS': 'The Walt Disney Company',
    'PYPL': 'PayPal Holdings, Inc.',
    'ADBE': 'Adobe Inc.',
    'CMCSA': 'Comcast Corporation',
    'NFLX': 'Netflix, Inc.',
    'XOM': 'Exxon Mobil Corporation',
    'VZ': 'Verizon Communications Inc.',
    'INTC': 'Intel Corporation',
    'T': 'AT&T Inc.',
    'CSCO': 'Cisco Systems, Inc.',
    'PFE': 'Pfizer Inc.',
    'PEP': 'PepsiCo, Inc.',
    'KO': 'The Coca-Cola Company',
    'ABT': 'Abbott Laboratories',
    'CRM': 'Salesforce.com, Inc.',
    'ORCL': 'Oracle Corporation',
    'TMO': 'Thermo Fisher Scientific Inc.',
    'WMT': 'Walmart Inc.',
    'ACN': 'Accenture plc',
    'COST': 'Costco Wholesale Corporation',
    'MCD': "McDonald's Corporation",
    'DHR': 'Danaher Corporation',
    'WFC': 'Wells Fargo & Company',
    'MDT': 'Medtronic plc',
    'LIN': 'Linde plc',
    'BMY': 'Bristol-Myers Squibb Company',
    'AVGO': 'Broadcom Inc.',
    'QCOM': 'QUALCOMM Incorporated',
    'NEE': 'NextEra Energy, Inc.',
    'TXN': 'Texas Instruments Incorporated',
    'NKE': 'NIKE, Inc.',
    'LLY': 'Eli Lilly and Company',
    'AMGN': 'Amgen Inc.',
    'LOW': "Lowe's Companies, Inc."
}




common_sense_ordering = [
    'AAPL',  # Apple Inc.
    'MSFT',  # Microsoft Corporation
    'GOOGL', # Alphabet Inc. Class A
    'GOOG',  # Alphabet Inc. Class C
    'META',  # Meta Platforms, Inc.
    'AMZN',  # Amazon.com, Inc.
    'NFLX',  # Netflix, Inc.
    'DIS',   # The Walt Disney Company
    'NVDA',  # NVIDIA Corporation
    'AMD',   # Advanced Micro Devices, Inc.
    'INTC',  # Intel Corporation
    'CSCO',  # Cisco Systems, Inc.
    'IBM',   # International Business Machines Corporation
    'ORCL',  # Oracle Corporation
    'ADBE',  # Adobe Inc.
    'CRM',   # Salesforce.com, Inc.
    'ACN',   # Accenture plc
    'TSLA',  # Tesla, Inc.
    'BRK-B', # Berkshire Hathaway Inc. Class B
    'JPM',   # JPMorgan Chase & Co.
    'BAC',   # Bank of America Corporation
    'WFC',   # Wells Fargo & Company
    'C',     # Citigroup Inc.
    'GS',    # The Goldman Sachs Group, Inc.
    'MS',    # Morgan Stanley
    'V',     # Visa Inc.
    'MA',    # Mastercard Incorporated
    'AXP',   # American Express Company
    'UNH',   # UnitedHealth Group Incorporated
    'JNJ',   # Johnson & Johnson
    'PFE',   # Pfizer Inc.
    'ABBV',  # AbbVie Inc.
    'MRK',   # Merck & Co., Inc.
    'ABT',   # Abbott Laboratories
    'LLY',   # Eli Lilly and Company
    'PG',    # The Procter & Gamble Company
    'KO',    # The Coca-Cola Company
    'PEP',   # PepsiCo, Inc.
    'WMT',   # Walmart Inc.
    'COST',  # Costco Wholesale Corporation
    'HD',    # The Home Depot, Inc.
    'LOW',   # Lowe's Companies, Inc.
    'NKE',   # NIKE, Inc.
    'MCD',   # McDonald's Corporation
    'SBUX',  # Starbucks Corporation
    'UNP',   # Union Pacific Corporation
    'UPS',   # United Parcel Service, Inc.
    'XOM',   # Exxon Mobil Corporation
    'CVX',   # Chevron Corporation
    'NEE',   # NextEra Energy, Inc.
]


common_sense_ordering = [
    # Information Technology (IT)
    'AAPL', 'MSFT', 'NVDA', 'AMD', 'INTC', 'CSCO', 'IBM', 'ORCL',
    'ADBE', 'CRM', 'ACN', 'TXN', 'QCOM',
    # Communication Services (CS)
    'GOOGL', 'GOOG', 'META', 'NFLX', 'DIS', 'CMCSA', 'VZ', 'T',
    # Consumer Discretionary (CD) - Technology-Driven Companies
    'AMZN', 'TSLA',
    # Consumer Discretionary (CD) - Traditional Retail and Services
    'HD', 'LOW', 'NKE', 'MCD', 'SBUX', 'TJX', 'BKNG',
    # Consumer Staples (CS)
    'PG', 'KO', 'PEP', 'WMT', 'COST',
    # Health Care (HC)
    'UNH', 'JNJ', 'PFE', 'ABBV', 'MRK', 'ABT', 'LLY', 'TMO', 'DHR', 'BMY',
    # Financials (F)
    'BRK-B', 'JPM', 'BAC', 'WFC', 'C', 'GS', 'MS', 'V', 'MA', 'AXP',
    # Real Estate (RE)
    'AMT', 'PLD',
    # Industrials (I)
    'UNP', 'UPS', 'BA', 'HON', 'CAT',
    # Materials (M)
    'LIN', 'APD', 'SHW',
    # Energy (E)
    'XOM', 'CVX', 'COP', 'SLB',
    # Utilities (U)
    'NEE', 'DUK', 'SO'
]

# %% [markdown]
# # Testing common sense against statistics
#
# I'm not really trying to bait here, and obviously one could use a combination.
# But here we shall use past correlations to define a seriation, and then use future correlations to define a seriation and judge the distance between the orderings.

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, leaves_list
from scipy.spatial.distance import squareform
import random


# Define window size (in months) for rolling correlation
window_size = 3  #


# Set a seed for reproducibility, or not
random.seed(42)
np.random.seed(42)


company_tickers = list(companies.keys())

# Define start and end dates
start_date = '2014-01-01'
end_date = '2023-09-30'

# Download adjusted close prices
prices = yf.download(company_tickers, start=start_date, end=end_date)['Adj Close']

# Calculate daily returns
returns = prices.pct_change().dropna()

# Add Month column
returns['Month'] = returns.index.to_period('M')

# Get list of unique months
months = returns['Month'].unique()



# Initialize lists to store current and future orderings
current_orderings = []
future_orderings = []

# Loop over months, ensuring we have enough future data
for i in range(window_size - 1, len(months) - 1):  # len(months) - 1 to have future data
    # Get the current month
    current_month = months[i]

    # Get the start month for the rolling window
    start_month = months[i - (window_size - 1)]

    # Get the data from start_month to current_month (inclusive)
    mask_current = (returns['Month'] >= start_month) & (returns['Month'] <= current_month)
    window_data_current = returns.loc[mask_current, company_tickers]

    # Compute the correlation matrix for current ordering
    corr_matrix_current = window_data_current.corr()

    # Convert correlations to distances
    distance_matrix_current = 1 - corr_matrix_current
    dist_array_current = squareform(distance_matrix_current.values, checks=False)

    # Perform hierarchical clustering for current ordering
    linkage_matrix_current = linkage(dist_array_current, method='average')
    leaves_current = leaves_list(linkage_matrix_current)
    ordering_current = corr_matrix_current.columns[leaves_current]

    # Append the current ordering and the current month
    current_orderings.append((current_month, list(ordering_current)))

    # Get the next month for future ordering
    next_month = months[i + 1]

    # Get the data for the next month only
    mask_future = (returns['Month'] == next_month)
    window_data_future = returns.loc[mask_future, company_tickers]

    # Compute the correlation matrix for future ordering
    corr_matrix_future = window_data_future.corr()

    # Convert correlations to distances
    distance_matrix_future = 1 - corr_matrix_future
    dist_array_future = squareform(distance_matrix_future.values, checks=False)

    # Perform hierarchical clustering for future ordering
    linkage_matrix_future = linkage(dist_array_future, method='average')
    leaves_future = leaves_list(linkage_matrix_future)
    ordering_future = corr_matrix_future.columns[leaves_future]

    # Append the future ordering and the next month
    future_orderings.append((next_month, list(ordering_future)))

# Function to generate all cyclic permutations and their reverses
def generate_cyclic_permutations(ordering):
    perms = []
    N = len(ordering)
    for i in range(N):
        # Cyclic permutation
        perm = ordering[i:] + ordering[:i]
        perms.append(perm)
        # Reverse cyclic permutation
        perm_rev = perm[::-1]
        perms.append(perm_rev)
    return perms

# Function to compute Hamming distance between two orderings
def hamming_distance(order1, order2):
    return sum(el1 != el2 for el1, el2 in zip(order1, order2))





# Generate a fixed random ordering
random_ordering = company_tickers.copy()
np.random.shuffle(random_ordering)

# Compute scores between the current ordering and future ordering
corr_scores = []

for (curr_month, curr_ordering), (future_month, future_ordering) in zip(current_orderings, future_orderings):
    # Generate all cyclic permutations of current ordering and their reverses
    cyclic_perms = generate_cyclic_permutations(curr_ordering)

    # Compute the minimal Hamming distance to the future ordering
    min_distance = np.inf
    for perm in cyclic_perms:
        dist = hamming_distance(perm, future_ordering)
        if dist < min_distance:
            min_distance = dist
    # Store the score and the month (associate with future_month)
    corr_scores.append((future_month.to_timestamp(), min_distance))

# Compute scores between the common sense ordering and future ordering
cs_scores = []

for (future_month, future_ordering) in future_orderings:
    # Generate all cyclic permutations of the common sense ordering and their reverses
    cyclic_perms = generate_cyclic_permutations(common_sense_ordering)

    # Compute the minimal Hamming distance to the future ordering
    min_distance = np.inf
    for perm in cyclic_perms:
        dist = hamming_distance(perm, future_ordering)
        if dist < min_distance:
            min_distance = dist
    # Store the score and the month
    cs_scores.append((future_month.to_timestamp(), min_distance))

# Compute scores between the random ordering and future ordering
random_scores = []

for (future_month, future_ordering) in future_orderings:
    # Generate all cyclic permutations of the random ordering and their reverses
    cyclic_perms = generate_cyclic_permutations(random_ordering)

    # Compute the minimal Hamming distance to the future ordering
    min_distance = np.inf
    for perm in cyclic_perms:
        dist = hamming_distance(perm, future_ordering)
        if dist < min_distance:
            min_distance = dist
    # Store the score and the month
    random_scores.append((future_month.to_timestamp(), min_distance))

# Convert scores to DataFrames
cs_scores_df = pd.DataFrame(cs_scores, columns=['Month', 'Score'])
cs_scores_df['Type'] = 'Common Sense'

random_scores_df = pd.DataFrame(random_scores, columns=['Month', 'Score'])
random_scores_df['Type'] = 'Random Ordering'

corr_scores_df = pd.DataFrame(corr_scores, columns=['Month', 'Score'])
corr_scores_df['Type'] = 'Correlation-Based'

# Combine the DataFrames
combined_scores_df = pd.concat([cs_scores_df, corr_scores_df, random_scores_df], ignore_index=True)

# Plot the scores over time
plt.figure(figsize=(14,7))
for score_type in ['Correlation-Based', 'Common Sense', 'Random Ordering']:
    subset = combined_scores_df[combined_scores_df['Type'] == score_type]
    plt.plot(subset['Month'], subset['Score'], marker='o', label=score_type)

plt.title('Ordering Similarity Scores Over Time (Top Companies)')
plt.xlabel('Month')
plt.ylabel('Score (Minimal Edit Distance to Future Ordering)')
plt.legend()
plt.grid(True)
plt.show()


print(combined_scores_df[['Type','Score']].groupby('Type').mean())
# Out:
# [*********************100%***********************]  51 of 51 completed
# <ipython-input-29-a7037709017c>:32: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   returns['Month'] = returns.index.to_period('M')
#                        Score
# Type
# Common Sense       46.812500
# Correlation-Based  45.854167
# Random Ordering    46.718750

# %% [markdown]
# # What was its reasoning?
#
# Certainly! Let's expand the list to include the top 50 companies by market capitalization in the S&P 500 and think carefully about their ordering within each sector. We'll group companies by their sectors and consider factors such as business models, products/services, market dynamics, and vulnerabilities to exogenous factors to create a logical, common sense ordering.
#
# Note: The list is based on data available up to my knowledge cutoff in September 2021. Some companies may have changed rankings or sectors since then.
#
# Top 50 Companies by Market Capitalization in the S&P 500 (Grouped by Sector)
# 1. Information Technology
# AAPL - Apple Inc.
# MSFT - Microsoft Corporation
# GOOGL - Alphabet Inc. Class A
# GOOG - Alphabet Inc. Class C
# NVDA - NVIDIA Corporation
# ADBE - Adobe Inc.
# CRM - Salesforce.com, Inc.
# CSCO - Cisco Systems, Inc.
# INTC - Intel Corporation
# ORCL - Oracle Corporation
# ACN - Accenture plc
# TXN - Texas Instruments Incorporated
# QCOM - QUALCOMM Incorporated
# AMD - Advanced Micro Devices, Inc.
# IBM - International Business Machines Corporation
# 2. Communication Services
# META - Meta Platforms, Inc. (formerly Facebook, Inc.)
# VZ - Verizon Communications Inc.
# T - AT&T Inc.
# NFLX - Netflix, Inc.
# DIS - The Walt Disney Company
# CMCSA - Comcast Corporation
# 3. Consumer Discretionary
# AMZN - Amazon.com, Inc.
# TSLA - Tesla, Inc.
# HD - The Home Depot, Inc.
# NKE - NIKE, Inc.
# MCD - McDonald's Corporation
# SBUX - Starbucks Corporation
# LOW - Lowe's Companies, Inc.
# BKNG - Booking Holdings Inc.
# TJX - The TJX Companies, Inc.
# 4. Health Care
# JNJ - Johnson & Johnson
# UNH - UnitedHealth Group Incorporated
# PFE - Pfizer Inc.
# ABBV - AbbVie Inc.
# MRK - Merck & Co., Inc.
# ABT - Abbott Laboratories
# TMO - Thermo Fisher Scientific Inc.
# DHR - Danaher Corporation
# LLY - Eli Lilly and Company
# BMY - Bristol-Myers Squibb Company
# 5. Financials
# BRK-B - Berkshire Hathaway Inc. Class B
# JPM - JPMorgan Chase & Co.
# V - Visa Inc.
# MA - Mastercard Incorporated
# BAC - Bank of America Corporation
# WFC - Wells Fargo & Company
# C - Citigroup Inc.
# GS - The Goldman Sachs Group, Inc.
# MS - Morgan Stanley
# AXP - American Express Company
# 6. Consumer Staples
# PG - The Procter & Gamble Company
# KO - The Coca-Cola Company
# PEP - PepsiCo, Inc.
# WMT - Walmart Inc.
# COST - Costco Wholesale Corporation
# 7. Industrials
# UNP - Union Pacific Corporation
# UPS - United Parcel Service, Inc.
# BA - The Boeing Company
# HON - Honeywell International Inc.
# CAT - Caterpillar Inc.
# 8. Energy
# XOM - Exxon Mobil Corporation
# CVX - Chevron Corporation
# COP - ConocoPhillips
# SLB - Schlumberger Limited
# 9. Utilities
# NEE - NextEra Energy, Inc.
# DUK - Duke Energy Corporation
# SO - The Southern Company
# 10. Materials
# LIN - Linde plc
# APD - Air Products and Chemicals, Inc.
# SHW - The Sherwin-Williams Company
# 11. Real Estate
# PLD - Prologis, Inc.
# AMT - American Tower Corporation
# Constructing the Common Sense Ordering
# Now, we'll think carefully within each sector to order the companies based on:
#
# Business Models and Operations
# Products and Services Offered
# Market Segments and Customer Base
# Sensitivity to Economic Factors
# Technological Innovation and Trends
# Detailed Ordering Within Each Sector
# Information Technology
# AAPL - Apple Inc.
#
# Consumer electronics, software, and services.
# Strong hardware focus with integration of software.
# MSFT - Microsoft Corporation
#
# Software, cloud services, enterprise solutions.
# Significant presence in both consumer and enterprise markets.
# GOOGL/GOOG - Alphabet Inc. Class A and C
#
# Internet-related services and products.
# Dominant in search, advertising, and emerging technologies like AI.
# META - Meta Platforms, Inc.
#
# Social media and virtual reality platforms.
# Focused on connecting people and building metaverse technologies.
# NVDA - NVIDIA Corporation
#
# Graphics processing units (GPUs), AI computing.
# Key player in gaming, data centers, and autonomous vehicles.
# AMD - Advanced Micro Devices, Inc.
#
# Semiconductors, CPUs, GPUs.
# Competitor to Intel and NVIDIA in processors and graphics.
# INTC - Intel Corporation
#
# Semiconductors, CPUs.
# Major supplier of processors for PCs and data centers.
# CSCO - Cisco Systems, Inc.
#
# Networking hardware, telecommunications equipment.
# Focused on enterprise networking and security solutions.
# ORCL - Oracle Corporation
#
# Database software, cloud engineered systems.
# Specializes in database management systems and enterprise software.
# ADBE - Adobe Inc.
#
# Multimedia and creativity software products.
# Leader in digital media and marketing solutions.
# CRM - Salesforce.com, Inc.
#
# Customer relationship management (CRM) software.
# Pioneer in cloud-based CRM solutions.
# IBM - International Business Machines Corporation
#
# IT services, software, hardware.
# Focused on enterprise solutions, cloud, and AI.
# ACN - Accenture plc
#
# Professional services, consulting.
# Provides strategy, consulting, and digital technology services.
# TXN - Texas Instruments Incorporated
#
# Semiconductors, analog chips.
# Specializes in analog and embedded processing products.
# QCOM - QUALCOMM Incorporated
#
# Semiconductors, telecommunications equipment.
# Leader in wireless technology and mobile communications.
# Communication Services
# DIS - The Walt Disney Company
#
# Entertainment, media networks, theme parks.
# Diverse entertainment portfolio with streaming services.
# NFLX - Netflix, Inc.
#
# Streaming entertainment services.
# Focused on original content and global streaming.
# CMCSA - Comcast Corporation
#
# Media, entertainment, telecommunications.
# Operates cable services and owns media content.
# VZ - Verizon Communications Inc.
#
# Telecommunications, wireless services.
# Provides communication services to consumers and businesses.
# T - AT&T Inc.
#
# Telecommunications, media, technology.
# Offers wireless, broadband, and content services.
# Consumer Discretionary
# AMZN - Amazon.com, Inc.
#
# E-commerce, cloud computing, digital streaming.
# Dominant in online retail and cloud services (AWS).
# TSLA - Tesla, Inc.
#
# Electric vehicles, energy storage.
# Innovator in EVs and renewable energy solutions.
# HD - The Home Depot, Inc.
#
# Home improvement retail.
# Largest home improvement retailer.
# LOW - Lowe's Companies, Inc.
#
# Home improvement retail.
# Second-largest home improvement retailer.
# NKE - NIKE, Inc.
#
# Athletic footwear, apparel.
# Global leader in sportswear.
# SBUX - Starbucks Corporation
#
# Coffeehouse chain.
# Leading specialty coffee retailer.
# MCD - McDonald's Corporation
#
# Fast-food restaurants.
# World's largest restaurant chain by revenue.
# TJX - The TJX Companies, Inc.
#
# Off-price retail stores.
# Operates discount apparel and home fashion stores.
# BKNG - Booking Holdings Inc.
#
# Online travel services.
# Provides travel and related services globally.
# Health Care
# UNH - UnitedHealth Group Incorporated
#
# Health care services, insurance.
# Largest health insurer in the U.S.
# JNJ - Johnson & Johnson
#
# Pharmaceuticals, medical devices, consumer goods.
# Diversified health care products company.
# PFE - Pfizer Inc.
#
# Pharmaceuticals.
# Researches, develops, and manufactures medicines.
# ABBV - AbbVie Inc.
#
# Biopharmaceuticals.
# Focus on immunology and oncology.
# MRK - Merck & Co., Inc.
#
# Pharmaceuticals, vaccines.
# Provides health solutions through medicines and vaccines.
# LLY - Eli Lilly and Company
#
# Pharmaceuticals.
# Develops products in neuroscience, endocrinology, oncology.
# ABT - Abbott Laboratories
#
# Medical devices, diagnostics, nutrition.
# Offers a broad range of health care products.
# TMO - Thermo Fisher Scientific Inc.
#
# Scientific instruments, reagents, consumables.
# Serves science research and clinical laboratories.
# DHR - Danaher Corporation
#
# Medical, industrial, commercial products.
# Focus on life sciences, diagnostics, environmental solutions.
# BMY - Bristol-Myers Squibb Company
#
# Pharmaceuticals.
# Develops drugs in oncology, cardiovascular diseases.
# Financials
# BRK-B - Berkshire Hathaway Inc. Class B
#
# Conglomerate holding company.
# Diverse holdings in insurance, utilities, manufacturing.
# JPM - JPMorgan Chase & Co.
#
# Banking, financial services.
# Largest U.S. bank by assets.
# BAC - Bank of America Corporation
#
# Banking, financial services.
# Offers consumer banking, wealth management.
# WFC - Wells Fargo & Company
#
# Banking, financial services.
# Provides consumer and commercial financial services.
# C - Citigroup Inc.
#
# Banking, financial services.
# Global bank with extensive international operations.
# GS - The Goldman Sachs Group, Inc.
#
# Investment banking, securities.
# Focus on investment management and financial services.
# MS - Morgan Stanley
#
# Investment banking, wealth management.
# Offers diversified financial services.
# V - Visa Inc.
#
# Payment technology.
# Facilitates electronic funds transfers worldwide.
# MA - Mastercard Incorporated
#
# Payment technology.
# Provides transaction processing and related services.
# AXP - American Express Company
#
# Financial services, credit cards.
# Offers charge and credit payment card products.
# Consumer Staples
# WMT - Walmart Inc.
#
# Retail, wholesale operations.
# World's largest company by revenue.
# COST - Costco Wholesale Corporation
#
# Membership-only warehouse clubs.
# Offers low-price, bulk goods.
# PG - The Procter & Gamble Company
#
# Consumer goods.
# Produces a wide range of household products.
# KO - The Coca-Cola Company
#
# Beverages.
# World's largest beverage company.
# PEP - PepsiCo, Inc.
#
# Beverages and snacks.
# Offers diversified food and beverage products.
# Industrials
# UNP - Union Pacific Corporation
#
# Railroad operations.
# Major freight hauling railroad.
# UPS - United Parcel Service, Inc.
#
# Package delivery, logistics.
# Global leader in logistics services.
# BA - The Boeing Company
#
# Aerospace, defense.
# Designs and manufactures airplanes, rotorcraft.
# HON - Honeywell International Inc.
#
# Aerospace, building technologies.
# Offers diversified industrial products.
# CAT - Caterpillar Inc.
#
# Construction and mining equipment.
# World's largest construction equipment manufacturer.
# Energy
# XOM - Exxon Mobil Corporation
#
# Oil and gas exploration, production.
# One of the world's largest publicly traded energy providers.
# CVX - Chevron Corporation
#
# Integrated energy company.
# Engaged in all aspects of the oil, gas, and geothermal industries.
# COP - ConocoPhillips
#
# Exploration and production of oil and natural gas.
# Focused on upstream activities.
# SLB - Schlumberger Limited
#
# Oilfield services.
# Provides technology for reservoir characterization, drilling.
# Utilities
# NEE - NextEra Energy, Inc.
#
# Electric utility holding company.
# Largest electric utility by market cap, focus on renewable energy.
# DUK - Duke Energy Corporation
#
# Electric power holding company.
# Operates in the U.S. and Latin America.
# SO - The Southern Company
#
# Gas and electric utility holding company.
# Provides energy in the southeastern U.S.
# Materials
# LIN - Linde plc
#
# Industrial gases and engineering.
# Supplies gases and services to various industries.
# APD - Air Products and Chemicals, Inc.
#
# Industrial gases, chemicals.
# Provides atmospheric and process gases.
# SHW - The Sherwin-Williams Company
#
# Paints, coatings.
# Leading manufacturer of paints and coatings.
# Real Estate
# AMT - American Tower Corporation
#
# Wireless communications infrastructure.
# Owns and operates wireless and broadcast communications infrastructure.
# PLD - Prologis, Inc.
#
# Logistics real estate.
# Owns industrial real estate focused on logistics facilities.
# Final Common Sense Ordering
# Now, we'll create a single ordering of all 50 companies, grouping similar companies together across sectors where appropriate. We'll consider cross-sector similarities, such as:
#
# Technology Companies: Grouped based on innovation and digital services.
# Financial Institutions: Banks and payment processors together.
# Consumer-Focused Companies: Retailers, consumer goods, and services.
# Healthcare Companies: Pharmaceutical and health services.
# Industrial and Energy Companies: Companies involved in physical infrastructure and energy.
# Common Sense Ordering:
#
# AAPL - Apple Inc.
# MSFT - Microsoft Corporation
# GOOGL - Alphabet Inc. Class A
# GOOG - Alphabet Inc. Class C
# META - Meta Platforms, Inc.
# AMZN - Amazon.com, Inc.
# NFLX - Netflix, Inc.
# DIS - The Walt Disney Company
# NVDA - NVIDIA Corporation
# AMD - Advanced Micro Devices, Inc.
# INTC - Intel Corporation
# CSCO - Cisco Systems, Inc.
# IBM - International Business Machines Corporation
# ORCL - Oracle Corporation
# ADBE - Adobe Inc.
# CRM - Salesforce.com, Inc.
# ACN - Accenture plc
# TSLA - Tesla, Inc.
# BRK-B - Berkshire Hathaway Inc. Class B
# JPM - JPMorgan Chase & Co.
# BAC - Bank of America Corporation
# WFC - Wells Fargo & Company
# C - Citigroup Inc.
# GS - The Goldman Sachs Group, Inc.
# MS - Morgan Stanley
# V - Visa Inc.
# MA - Mastercard Incorporated
# AXP - American Express Company
# UNH - UnitedHealth Group Incorporated
# JNJ - Johnson & Johnson
# PFE - Pfizer Inc.
# ABBV - AbbVie Inc.
# MRK - Merck & Co., Inc.
# ABT - Abbott Laboratories
# LLY - Eli Lilly and Company
# PG - The Procter & Gamble Company
# KO - The Coca-Cola Company
# PEP - PepsiCo, Inc.
# WMT - Walmart Inc.
# COST - Costco Wholesale Corporation
# HD - The Home Depot, Inc.
# LOW - Lowe's Companies, Inc.
# NKE - NIKE, Inc.
# MCD - McDonald's Corporation
# SBUX - Starbucks Corporation
# UNP - Union Pacific Corporation
# UPS - United Parcel Service, Inc.
# XOM - Exxon Mobil Corporation
# CVX - Chevron Corporation
# NEE - NextEra Energy, Inc.
# Explanation of the Ordering:
#
# Positions 1-17: Technology and Communication Services companies are grouped together, reflecting their interrelated markets, technological innovations, and similar market dynamics.
#
# Positions 18-19: TSLA is placed after tech companies due to its innovative approach in automotive and energy, bridging technology and industrial sectors. BRK-B follows as a conglomerate with diverse holdings, some overlapping with tech and consumer sectors.
#
# Positions 20-28: Financial institutions are grouped, starting with major banks (JPM, BAC, WFC, C), followed by investment banks (GS, MS), and then payment processors (V, MA, AXP).
#
# Positions 29-35: Healthcare companies are grouped, starting with health services (UNH), followed by pharmaceuticals and medical devices (JNJ, PFE, ABBV, MRK, ABT, LLY).
#
# Positions 36-40: Consumer Staples companies are grouped, reflecting essential consumer products and retail (PG, KO, PEP, WMT, COST).
#
# Positions 41-45: Consumer Discretionary companies are grouped, focusing on retail and consumer services (HD, LOW, NKE, MCD, SBUX).
#
# Positions 46-47: Industrials are grouped with transportation and logistics companies (UNP, UPS).
#
# Positions 48-49: Energy companies are grouped (XOM, CVX), reflecting their involvement in oil and gas.
#
# Position 50: NEE represents utilities, particularly with a focus on renewable energy, bridging energy and utilities sectors.
#
# Using the Common Sense Ordering in the Analysis
# This expanded and carefully considered common sense ordering takes into account:
#
# Sector Groupings: Companies are grouped by their primary sectors to reflect inherent similarities.
#
# Business Relationships: Companies with overlapping business areas or supply chains are placed closer together.
#
# Market Dynamics: Consideration of how companies respond to economic factors, technological changes, and consumer behavior.
#
# Innovation and Growth Potential: Technology and innovative companies are placed at the beginning due to their significant impact on market trends.
#
# By using this ordering in the analysis, we aim to see how well a logically constructed ordering based on fundamental business similarities predicts future correlations among the top 50 companies.
#
# Next Steps in the Analysis
# Update the Code:
#
# Adjust the list of companies (companies dictionary and company_tickers list) to include all 50 companies.
#
# Update the common_sense_ordering list with the new ordering.
#
# Perform the Analysis:
#
# Follow the same steps as before to compute the correlation-based orderings, random ordering, and minimal edit distances.
#
# Compare the common sense ordering to future correlation-based orderings.
#
# Interpret the Results:
#
# Analyze whether the expanded common sense ordering provides better predictive power compared to the random ordering.
#
# Assess how the increased number of companies affects the minimal edit distances and overall trends.
#
# Final Thoughts
# By thinking carefully within each sector and constructing a detailed common sense ordering, we aim to create a meaningful benchmark to compare against statistically derived orderings. This approach considers the qualitative aspects of the companies, which may not be fully captured by historical correlations alone.
